# %% [markdown]
# ## Подключение необходимых библиотек

# %%
from plotnine import *
from plotnine.data import *

import numpy as np
import pandas as pd

import warnings

# %% [markdown]
# ## Тестовый датафрейм "mpg"

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# 229  midsize
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize
#
# [234 rows x 11 columns]

# %% [markdown]
# ## Простейшая визуализация с использованиме geom_point по осям displ и hwy

# %%
ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="hwy"))
# Out:
# <ggplot: (22658497)>

# %% [markdown]
# ### Постройте два графика: в одном из них одна из осей должна быть соответствовать столбцу с элементами-категориями, во втором – обе (например, "class" и "drv")

# %%
# Type your code here...

ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="manufacturer"))
# Out:
# <ggplot: (22774297)>

# %%
# Type your code here...

ggplot(data=mpg) +\
geom_point(mapping=aes(x="class", y="manufacturer"))
# Out:
# <ggplot: (22657895)>

# %% [markdown]
# ## Добавим красок, оттенков и форм в графики

# %%
ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="hwy", color="class"))
# Out:
# <ggplot: (22871790)>

# %%
ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="hwy", alpha="manufacturer"))
# Out:
# C:\Users\Barova\AppData\Roaming\Python\Python38\site-packages\plotnine\scales\scale_alpha.py:68: PlotnineWarning: Using alpha for a discrete variable is not advised.
# <ggplot: (23019843)>

# %%
ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="hwy", shape="manufacturer"))
# Out:
# C:\Users\Barova\AppData\Roaming\Python\Python38\site-packages\mizani\palettes.py:670: UserWarning: Palette can return a maximum of 13 values. 15 values requested.
# C:\Users\Barova\AppData\Roaming\Python\Python38\site-packages\plotnine\layer.py:411: PlotnineWarning: geom_point : Removed 61 rows containing missing values.
# C:\Users\Barova\AppData\Roaming\Python\Python38\site-packages\mizani\palettes.py:670: UserWarning: Palette can return a maximum of 13 values. 15 values requested.
# C:\Users\Barova\AppData\Roaming\Python\Python38\site-packages\plotnine\guides\guides.py:253: PlotnineWarning: geom_point legend : Removed 2 rows containing missing values.
# <ggplot: (23170841)>

# %% [markdown]
# ### Попробуйте сделать два графика: в одном размер точек будет соответствовать столбцу с элементами-категориями, во втором – столбцу с элементами-значениями

# %%
# Type your code here...

ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="hwy", size="manufacturer"))
# Out:
# C:\Users\Barova\AppData\Roaming\Python\Python38\site-packages\plotnine\scales\scale_size.py:48: PlotnineWarning: Using size for a discrete variable is not advised.
# <ggplot: (23336635)>

# %%
# Type your code here...


ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="hwy", size="cty"))
# Out:
# <ggplot: (23498289)>

# %% [markdown]
# ## А что если сделать использовать в качестве источника визуального свойства "форма" непрерывную категорию (например hwy)?

# %%
# Type your code here...

ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="hwy",shape="manufacturer"))
# Out:
# C:\Users\Barova\AppData\Roaming\Python\Python38\site-packages\mizani\palettes.py:670: UserWarning: Palette can return a maximum of 13 values. 15 values requested.
# C:\Users\Barova\AppData\Roaming\Python\Python38\site-packages\plotnine\layer.py:411: PlotnineWarning: geom_point : Removed 61 rows containing missing values.
# C:\Users\Barova\AppData\Roaming\Python\Python38\site-packages\mizani\palettes.py:670: UserWarning: Palette can return a maximum of 13 values. 15 values requested.
# C:\Users\Barova\AppData\Roaming\Python\Python38\site-packages\plotnine\guides\guides.py:253: PlotnineWarning: geom_point legend : Removed 2 rows containing missing values.
# <ggplot: (23644796)>

# %% [markdown]
# ### Попробуйте сделать график с визуальным элементом, заданным условным оператором (например, color="displ < 5")

# %%
# Type your code here...

ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="manufacturer", color="displ<5"))
# Out:
# <ggplot: (23813870)>

# %%
ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="manufacturer", shape="hwy>29", color="hwy>29"))
# Out:
# <ggplot: (23873235)>

# %% [markdown]
# ### Попробуйте поэкспериментировать с графиками, где одной категории соответствуют различные визуальные элементы (пример ниже). Попробуйте привести пример, когда это имеет смысл.

# %%
ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="manufacturer", stroke="hwy"))
# Out:
# <ggplot: (24681042)>

# %%
ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="manufacturer", stroke="hwy", color="manufacturer"))
# Out:
# <ggplot: (26964240)>

# %%
# Type your code here...

ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="manufacturer", stroke="hwy", color="class"))
# Out:
# <ggplot: (22885828)>

# %%
ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="manufacturer", color="class", size="hwy"))
# Out:
# <ggplot: (24062245)>

# %% [markdown]
# ## Использование панелей при визуализации

# %%
ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="hwy")) +\
facet_wrap("class", nrow=2)
# Out:
# <ggplot: (23502836)>

# %%
ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="hwy")) +\
facet_grid("drv ~ cyl")
# Out:
# <ggplot: (27310445)>

# %% [markdown]
# ### Что если использовать категорию с непрерывными значениями (например, hwy) для разделения на панели?

# %%
# Type your code here...

ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="class")) +\
facet_wrap("hwy", nrow=2)
# Out:
# <ggplot: (22985105)>

# %% [markdown]
# ### Можно сделать только вертикальные или только горизонтальные панели, если использовать конструкцию типа (". ~ <категория>")

# %%
# Type your code here...

ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="hwy")) +\
facet_grid(". ~ class")
# Out:
# <ggplot: (28893106)>

# %%
# Type your code here...

ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="hwy")) +\
facet_grid("class ~ .")
# Out:
# <ggplot: (24066118)>

# %% [markdown]
# ### Что лучше использовать: цвета или панели? А для большого набора?

# %% [markdown]
# ## geom_smooth() позволяет получить сглаженную среднюю (в том числе, с доверительным интервалом).abs
# ### (это не сработает без библиотеки scikit-misc, и может не сработать даже с ней)

# %%
ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="hwy"))
# Out:
# <ggplot: (24660661)>

# %%
ggplot(data=mpg) +\
geom_smooth(mapping=aes(x="displ", y="hwy"))
# Out:
# C:\Users\Barova\AppData\Roaming\Python\Python38\site-packages\plotnine\stats\smoothers.py:321: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.
# <ggplot: (29105442)>

# %%
ggplot(data=mpg) +\
geom_smooth(mapping=aes(x="displ", y="hwy", linetype="drv"))
# Out:
# C:\Users\Barova\AppData\Roaming\Python\Python38\site-packages\plotnine\stats\smoothers.py:321: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.
# C:\Users\Barova\AppData\Roaming\Python\Python38\site-packages\plotnine\stats\smoothers.py:321: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.
# C:\Users\Barova\AppData\Roaming\Python\Python38\site-packages\plotnine\stats\smoothers.py:321: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.
# <ggplot: (23760297)>

# %%
ggplot(data=mpg, mapping=aes(x="displ", y="hwy", color="drv")) +\
geom_point() +\
geom_smooth(mapping=aes(linetype="drv"))
# Out:
# C:\Users\Barova\AppData\Roaming\Python\Python38\site-packages\plotnine\stats\smoothers.py:321: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.
# C:\Users\Barova\AppData\Roaming\Python\Python38\site-packages\plotnine\stats\smoothers.py:321: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.
# C:\Users\Barova\AppData\Roaming\Python\Python38\site-packages\plotnine\stats\smoothers.py:321: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.
# <ggplot: (23045720)>

# %% [markdown]
# ## Визуальные отображения в функции ggplot будут распространяться на все графики. Отдельные свойства каждого геометрического отображения будут относиться только к нему.

# %%
ggplot(data=mpg, mapping=aes(x="displ", y="hwy")) +\
geom_point(mapping=aes(color="class")) +\
geom_smooth()
# Out:
# C:\Users\Barova\AppData\Roaming\Python\Python38\site-packages\plotnine\stats\smoothers.py:321: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.
# <ggplot: (23760321)>

# %%
ggplot(data=mpg, mapping=aes(x="displ", y="hwy")) +\
geom_point(mapping=aes(color="class")) +\
geom_smooth(data=mpg.loc[mpg["class"] == "subcompact"], se=False)
# Out:
# <ggplot: (22979350)>

# %% [markdown]
# ## Попробуйте скомбинировать разные свойства разных слоёв

# %%
# Type your code here...

# %% [markdown]
# # Какое геометрическое отображение вы будете использовать, чтобы нарисовать линейную диаграмму (обычный линейный график)?

# %%
# Type your code here...

ggplot(data=mpg, mapping=aes(x="displ", y="hwy")) +\
geom_line(mapping=aes(color="class"))
# Out:
# <ggplot: (28821691)>

# %% [markdown]
# ### Подберите подходящий код под следующие графики:
# <img src="supp/p1.png" alt="Drawing" style="width: 350px;"/>
# <img src="supp/p2.png" alt="Drawing" style="width: 350px;"/></br>
# <img src="supp/p3.png" alt="Drawing" style="width: 350px;"/>
# <img src="supp/p4.png" alt="Drawing" style="width: 350px;"/></br>
# <img src="supp/p5.png" alt="Drawing" style="width: 350px;"/>
# <img src="supp/p6.png" alt="Drawing" style="width: 350px;"/>

# %%
# Type your code here...

ggplot(data=mpg, mapping=aes(x="displ", y="hwy")) +\
geom_point() +\
geom_smooth(data=mpg.loc[mpg["class"] == "subcompact"], se=False)
# Out:
# <ggplot: (23397651)>

# %%
# Type your code here...

ggplot(data=mpg, mapping=aes(x="displ", y="hwy")) +\
geom_point() +\
geom_smooth(mapping=aes(linetype="drv"))
# Out:
# C:\Users\Barova\AppData\Roaming\Python\Python38\site-packages\plotnine\stats\smoothers.py:321: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.
# C:\Users\Barova\AppData\Roaming\Python\Python38\site-packages\plotnine\stats\smoothers.py:321: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.
# C:\Users\Barova\AppData\Roaming\Python\Python38\site-packages\plotnine\stats\smoothers.py:321: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.
# <ggplot: (23695710)>

# %%
# Type your code here...

ggplot(data=mpg, mapping=aes(x="displ", y="hwy")) +\
geom_point(mapping=aes(color="drv")) +\
geom_smooth(data=mpg.loc[mpg["class"] == "subcompact"], se=False)
# Out:
# <ggplot: (29283347)>

# %%
ggplot(data=mpg, mapping=aes(x="displ", y="hwy")) +\
geom_point(mapping=aes(color="drv")) +\
geom_smooth()
# Out:
# C:\Users\Barova\AppData\Roaming\Python\Python38\site-packages\plotnine\stats\smoothers.py:321: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.
# <ggplot: (29333550)>

# %%
# Type your code here...

ggplot(data=mpg, mapping=aes(x="displ", y="hwy", color="drv")) +\
geom_point() +\
geom_smooth(mapping=aes(linetype="drv"), color='black')
# Out:
# C:\Users\Barova\AppData\Roaming\Python\Python38\site-packages\plotnine\stats\smoothers.py:321: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.
# C:\Users\Barova\AppData\Roaming\Python\Python38\site-packages\plotnine\stats\smoothers.py:321: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.
# C:\Users\Barova\AppData\Roaming\Python\Python38\site-packages\plotnine\stats\smoothers.py:321: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.
# <ggplot: (28773286)>

# %%
# Type your code here...
ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="hwy",color="drv"))
# Out:
# <ggplot: (23748491)>

# %% [markdown]
# ## Статистические свойства элементов категорий

# %%
ggplot(data=diamonds) +\
geom_bar(mapping=aes(x="cut"))
# Out:
# <ggplot: (24016749)>

# %%
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# ### Что делает geom_col()? Чем он отличается от geom_bar()?

# %% [markdown]
# geom_bar() - высота пропорциональна количеству элементов (или сумме весов, если weight задан)
#
# geom_col() - высота столбцов демонстрирует значения в данных

# %%
ggplot(data=diamonds) +\
geom_col(mapping=aes(x="cut", y="price"))
# Out:
# <ggplot: (23206663)>

# %% [markdown]
# ### Что произойдёт, если
# 'ggplot(data=diamonds) +\
# 'geom_bar(mapping=aes(x="cut", y="..prop.."), group=1)
# или
# ggplot(data=diamonds) +\
# geom_bar(mapping=aes(x="cut", fill="color", y="..prop.."))
# ### запустить без "group=1"? Почему?

# %%
# Type your code here...

ggplot(data=diamonds) +\
geom_bar(mapping=aes(x="cut", y="..prop.."), group=1)
# Out:
# <ggplot: (32617744)>

# %%
# Type your code here...

ggplot(data=diamonds) +\
geom_bar(mapping=aes(x="cut", fill="clarity", y="..prop.."))
# Out:
# <ggplot: (22727256)>

# %% [markdown]
# ## Модные графики с красивыми цветами

# %%
ggplot(data=diamonds) +\
geom_bar(mapping=aes(x="cut", fill="cut"))
# Out:
# <ggplot: (24049740)>

# %% [markdown]
# ## При добавлении новых категорий в качестве цвета появляется новая функциональность

# %%
ggplot(data=diamonds) +\
geom_bar(mapping=aes(x="cut", fill="clarity"))
# Out:
# <ggplot: (29049432)>

# %%
ggplot(data=diamonds, mapping=aes(x="cut", colour="clarity")) +\
geom_bar(fill=None, position="identity")
# Out:
# <ggplot: (23860143)>

# %%
ggplot(data=diamonds) +\
geom_bar(mapping=aes(x="cut", fill="clarity"), position="fill")
# Out:
# <ggplot: (23314508)>

# %%
ggplot(data=diamonds) +\
geom_bar(mapping=aes(x="cut", fill="clarity"), position="dodge")
# Out:
# <ggplot: (28958193)>

# %% [markdown]
# ## Добавим jitter в scatter!

# %%
ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="hwy"), position="jitter")
# Out:
# <ggplot: (22848832)>

# %% [markdown]
# ### Зачем тут coord_fixed()? Что делает geom_abline()?

# %%
ggplot(data=mpg, mapping=aes(x="cty", y="hwy")) +\
geom_point() +\
geom_abline() +\
coord_fixed()
# Out:
# <ggplot: (23859273)>

# %% [markdown]
# # Творческое задание
# ## Попробуйте использовать изученные средства plotnine для своего датасета (необязательно много и пока не надо строить сложные графики)

# %%
pip show plotnine
# Out:
# Name: plotnine
# Version: 0.10.1
# Summary: A grammar of graphics for python
# Home-page: https://plotnine.readthedocs.io/en/stable
# Author: Hassan Kibirige
# Author-email: has2k1@gmail.com
# License: MIT
# Location: c:\users\barova\appdata\roaming\python\python38\site-packages
# Requires: matplotlib, mizani, numpy, pandas, patsy, scipy, statsmodels
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv('abalone.csv', sep=',')
df.head()
# Out:
#   Sex  Length  Diameter  Height  WholeWeight  ShuckedWeight  VisceraWeight  \
# 0   M   0.455     0.365   0.095       0.5140         0.2245         0.1010
# 1   M   0.350     0.265   0.090       0.2255         0.0995         0.0485
# 2   F   0.530     0.420   0.135       0.6770         0.2565         0.1415
# 3   M   0.440     0.365   0.125       0.5160         0.2155         0.1140
# 4   I   0.330     0.255   0.080       0.2050         0.0895         0.0395
#
#    ShellWeight  Rings
# 0        0.150     15
# 1        0.070      7
# 2        0.210      9
# 3        0.155     10
# 4        0.055      7

# %% [markdown]
# Столбцы:
#
# - Sex - Пол (мужской, женский, ребенок). Категориальный признак.
#
# - Length - Длина (самое длинный замер раковины). Вещественный тип.
#
# - Diameter - Диаметр (замеряется перпендикулярно длине). Вещественный тип.
#
# - Height - Высота (моллюск с панцирем). Вещественный тип.
#
# - WholeWeight - Полный вес. Вещественный тип.
#
# - ShuckedWeight - Вес моллюска (без раковины). Вещественный тип.
#
# - VisceraWeight - Вес внутренностей моллюска (после "кровотечения"). Вещественный тип.
#
# - ShellWeight - Вес корпуса (после сушки). Вещественный тип.
#
# - Rings - Кольца (дает возраст в годах). Целочисленный тип.

# %%
# поделим на 3 условных возрастных группы
df['Age'] = df.apply(lambda row: round(row['Rings']/9 + 1), axis = 1)
df.head(3)
# Out:
#   Sex  Length  Diameter  Height  WholeWeight  ShuckedWeight  VisceraWeight  \
# 0   M   0.455     0.365   0.095       0.5140         0.2245         0.1010
# 1   M   0.350     0.265   0.090       0.2255         0.0995         0.0485
# 2   F   0.530     0.420   0.135       0.6770         0.2565         0.1415
#
#    ShellWeight  Rings  Age
# 0         0.15     15    3
# 1         0.07      7    2
# 2         0.21      9    2

# %%
df1 = df.replace({'Age':{1:'baby', 2:'young', 3: 'adult', 4:'old'}})
df1.head(3)
# Out:
#   Sex  Length  Diameter  Height  WholeWeight  ShuckedWeight  VisceraWeight  \
# 0   M   0.455     0.365   0.095       0.5140         0.2245         0.1010
# 1   M   0.350     0.265   0.090       0.2255         0.0995         0.0485
# 2   F   0.530     0.420   0.135       0.6770         0.2565         0.1415
#
#    ShellWeight  Rings    Age
# 0         0.15     15  adult
# 1         0.07      7  young
# 2         0.21      9  young

# %%
ggplot(data=df1, mapping=aes(x="Length", y="Diameter")) +\
geom_point(mapping=aes(color='Age')) +\
geom_abline() +\
coord_fixed()
# Out:
# <ggplot: (34348945)>

# %%
ggplot(data=df1) +\
geom_point(mapping=aes(x="Length", y="Diameter", color="Rings>10"))
# Out:
# <ggplot: (23624403)>

# %%
ggplot(data=df1) +\
geom_bar(mapping=aes(x="Age", fill="Sex"), position="dodge")
# Out:
# <ggplot: (28919080)>

# %%
ggplot(data=df1) +\
geom_bar(mapping=aes(x="Sex", fill="Age"))
# Out:
# <ggplot: (23003525)>
